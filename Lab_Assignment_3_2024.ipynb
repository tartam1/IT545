# %% [markdown]
# <a href="https://colab.research.google.com/github/tartam1/IT545/blob/main/Lab_Assignment_3_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 5.1 Introduction to pandas Data Structures

# %%
# Import Series and DataFrame into local namespace
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ## Problem 1

# %% [markdown]
# #### In this problem, you will create a series with an index identifying each data point. The series will contain the numbers 4, 7, -5, 3. The index will be d, b, a and c.

# %%
# Insert commenting and code in this cell.
# Set up the data in numbers and the index.
# I am also having the info displayd to validate and for my own sanity.
numbers = [4, 7, -5, 3]
index = ['d', 'b', 'a', 'c']
series = pd.Series(numbers, index=index)
series
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %% [markdown]
# ## Problem 2

# %% [markdown]
# #### In this problem, demonstrate how you would check for the value 'b' in the series created above.

# %%
# Insert commenting and code in this cell.
# simple check for b value. I wanted to just check another way with and without
# print
print('b' in series)
print("Another way to check for b value")
'b' in series
# Out:
# True
# Another way to check for b value
# True

# %% [markdown]
# ## Problem 3

# %% [markdown]
# #### In this problem, you are going to create a Series by passing the dict. This occurs when you have data contained in a Python dict (dictionary). Create a dictionary with the following. Create, pass values, display the values and run isnull to see if any of the values in the Series are null.
# <br>
# Ohio - 35000<br>
# Texas - 71000<br>
# Oregon - 16000<br>
# Utah - 5000<br>

# %%
# Insert commenting and code in this cell.
# set up dictionary
data_dict = {
    'Ohio': 35000,
    'Texas': 71000,
    'Oregon': 16000,
    'Utah': 5000
}

# Create the series and assign
series = pd.Series(data_dict)

# Show it
print(series)

# Check if it is null
pd.isnull(series)
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64
# Ohio      False
# Texas     False
# Oregon    False
# Utah      False
# dtype: bool

# %% [markdown]
# ## Problem 4

# %% [markdown]
# #### In this problem, you will be creating a DataFrame from a dict of equal-length lists. <br>
# Create the DataFrame, assign it to the frame variable and display it.<br>
# state: Ohio, Ohio, Ohio, Nevada, Nevada, Nevada<br>
# year: 2000, 2001, 2002, 2001, 2002, 2003<br>
# pop: 1.5, 1.7, 3.6, 2.4, 2.9, 3.2<br>

# %%
# Insert commenting and code in this cell.
# set up data
data = {
    'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
    'year': [2000, 2001, 2002, 2001, 2002, 2003],
    'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
}

# Create the frame
frame = pd.DataFrame(data)

# Show it
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# ## Problem 5

# %% [markdown]
# #### In this problem, you are going to add a new column named debt with the default value of 21, 25, 29, 33, 36, 44 for all existing records. Complete this and display the updated DataFrame. This will be using frame from Problem 4.

# %%
# Insert commenting and code in this cell.
# using the information from the previous question
# update/add to frame
frame['debt'] = [21, 25, 29, 33, 36, 44]

# Show it
frame
# Out:
#     state  year  pop  debt
# 0    Ohio  2000  1.5    21
# 1    Ohio  2001  1.7    25
# 2    Ohio  2002  3.6    29
# 3  Nevada  2001  2.4    33
# 4  Nevada  2002  2.9    36
# 5  Nevada  2003  3.2    44

# %% [markdown]
# ## Problem 6

# %% [markdown]
# #### In this problem, please remove the column debt from the frame DataFrame and display the contenst of frame.

# %%
# Insert commenting and code in this cell.
# doing drop and using the string column instead of 1 for readiblity
# I did it both ways in testing
frame = frame.drop('debt', axis='columns')

# Show it
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# # Section 5.3 Summarizing and Computing Descriptive Statistics

# %% [markdown]
# ## Problem 7

# %% [markdown]
# #### In this problem, you will create a DataFrame - df - that will look like the table below. You will need to display the table. <br>
#
# a 1.40  NaN<br>
# b 7.10 -4.5<br>
# c  NaN  NaN<br>
# d 0.75 -1.3<br>

# %%
# Insert commenting and code in this cell.
# create the dataframe
data = {
    'first': [1.40, 7.10, np.nan, 0.75],
    'second': [np.nan, -4.5, np.nan, -1.3]
}

# add index I saw in book it can be done in one command but wanted to try
# it differently
df = pd.DataFrame(data, index=['a', 'b', 'c', 'd'])

# pring
df
# Out:
#    first  second
# a   1.40     NaN
# b   7.10    -4.5
# c    NaN     NaN
# d   0.75    -1.3

# %% [markdown]
# ## Problem 8

# %% [markdown]
# #### In this problem, (1) Use the DataFrame sum method to return the Series containing column sums and (2) use the DataFrame describe method to produce summary statistics. use the DataFrame df from Problem 7.

# %%
# Insert commenting and code in this cell.
# I am finding I have to add some prints to force the output. I am using colab
# lets sum and get the coummn of sums
df.sum()
print(df)
print("-----------------")

# lets pass in axis columns
df.sum(axis='columns')
print(df)
print("-----------------")

# lets describe
print(df.describe())
# Out:
#    first  second
# a   1.40     NaN
# b   7.10    -4.5
# c    NaN     NaN
# d   0.75    -1.3
# -----------------
#    first  second
# a   1.40     NaN
# b   7.10    -4.5
# c    NaN     NaN
# d   0.75    -1.3
# -----------------
#           first    second
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %% [markdown]
# ## Problem 9

# %% [markdown]
# #### In this problem, you will type out the input lines under the section 5.3 Summarizing and Computing Descriptive Statistics heading - stopping before the sub-heading titled Correlation and Covariance.

# %%
# Insert commenting and code in this cell.
# starting the dataframe
df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],[np.nan, np.nan], [0.75, -1.3]],
                  index=["a", "b", "c", "d"], columns=["one", "two"])
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
# data frames sums
df.sum()
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
# more sums
df.sum(axis="columns")
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %%
# working with nas
df.sum(axis="index", skipna=False)
# Out:
# one   NaN
# two   NaN
# dtype: float64

# %%
# more this time columns
df.sum(axis="columns", skipna=False)
# Out:
# a     NaN
# b    2.60
# c     NaN
# d   -0.55
# dtype: float64

# %%
# gettting mean on columns
df.mean(axis="columns")
# Out:
# a    1.400
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %%
# some more indirect statistics
df.idxmax()
# Out:
# one    b
# two    d
# dtype: object

# %%
# accoumulations
df.cumsum()
# Out:
#     one  two
# a  1.40  NaN
# b  8.50 -4.5
# c   NaN  NaN
# d  9.25 -5.8

# %%
# summary statistics
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
# nonnumeric data describe
obj = pd.Series(["a", "a", "b", "c"] * 4)
obj.describe()
# Out:
# count     16
# unique     3
# top        a
# freq       8
# dtype: object

# %% [markdown]
# ## Problem 10

# %% [markdown]
# #### In this problem, you will the unique function to give an array of unique values in a Series. First, create the series obj using the values below. <br>
# c, a, d, a, a, b, b, c, c<br>

# %%
# Insert commenting and code in this cell.
# Create series
my_series = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])

# use unique
my_unique_values = my_series.unique()

# print
print(my_unique_values)
# Out:
# ['c' 'a' 'd' 'b']
